# %%
from minio import Minio
import pandas as pd
from io import StringIO

# %%
client = Minio(
    "172.21.0.3:9000",
    access_key="minio",
    secret_key="minio123",
    secure=False)

# %%
#data_order_items = obj_order_items.read()

client.fget_object('processing', 'olist_orders.parquet', '/processing')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /tmp/ipykernel_21906/3108201566.py in <module>
#       1 #data_order_items = obj_order_items.read()
#       2
# ----> 3 client.fget_object('processing', 'olist_orders.parquet', '/processing')
#
# ~/.pyenv/versions/3.8.5/envs/ds/lib/python3.8/site-packages/minio/api.py in fget_object(self, bucket_name, object_name, file_path, request_headers, ssec, version_id, extra_query_params, tmp_file_path)
#    1062                 extra_query_params=extra_query_params,
#    1063             )
# -> 1064             with open(tmp_file_path, "ab") as tmp_file:
#    1065                 for data in response.stream(amt=1024*1024):
#    1066                     tmp_file.write(data)
#
# PermissionError: [Errno 13] Permission denied: '/processing.0d7e5c1fb5c175fb9ea5f3cddfa7468e-3.part.minio'

# %%
data_order = StringIO(str(data_order_items, 'utf-8')) 
df_order = pd.read_parquet(data_order)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipykernel_21906/122554236.py in <module>
# ----> 1 data_order = StringIO(str(data_order_items, 'utf-8'))
#       2 df_order = pd.read_parquet(data_order)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc8 in position 7: invalid continuation byte

# %%
df.head()
# Out:
# Empty DataFrame
# ...

# %%
df.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
df.rename(columns={'order_item_id': 'quantity'}, inplace=True)
df.drop(columns=['seller_id'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                            order_id  quantity  \
# 0  00010242fe8c5a6d1ba2dd792cb16214         1
# 1  00018f77f2f0320c557190d7a144bdd3         1
# 2  000229ec398224ef6ca0657da4fc703e         1
# 3  00024acbcdf0a6daa1e931b038114c75         1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9         1
#
#                          product_id  shipping_limit_date   price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  2017-09-19 09:45:35   58.90
# 1  e5f2d52b802189ee658865ca93d83a8f  2017-05-03 11:05:13  239.90
# 2  c777355d18b72b67abbeef9df44fd0fd  2018-01-18 14:48:30  199.00
# 3  7634da152a4610f1595efa32f14722fc  2018-08-15 10:10:18   12.99
# 4  ac6c3623068f30de03045865e4e10089  2017-02-13 13:57:51  199.90
#
#    freight_value
# 0          13.29
# 1          19.93
# 2          17.87
# 3          12.79
# 4          18.14
